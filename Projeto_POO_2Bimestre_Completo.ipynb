# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Enquete_Jhony:
    def __init__(self, titulo, descricao, ativo):
        self.titulo = titulo
        self.descricao = descricao
        self.ativo = ativo

    def exibir_dados_Jhony(self):
        return f"Título: {self.titulo}\nDescrição: {self.descricao}\nAtiva: {self.ativo}"

enquete1 = Enquete_Jhony("Melhor horário para aula extra", "Escolha o melhor horário.", True)
enquete2 = Enquete_Jhony("Tema da próxima feira", "Vote no melhor tema para a feira escolar.", False)

print(enquete1.exibir_dados_Jhony())
# Out:
# Título: Melhor horário para aula extra
# Descrição: Escolha o melhor horário.
# Ativa: True

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class Enquete_Jhony:
    def __init__(self, titulo, descricao, ativo):
        self.titulo = titulo
        self.descricao = descricao
        self.ativo = ativo

    def ativar_enquete_Jhony(self):
        self.ativo = True

    def desativar_enquete_Jhony(self):
        self.ativo = False

class EnqueteComVotos_Jhony(Enquete_Jhony):
    def __init__(self, titulo, descricao, ativo, votos):
        super().__init__(titulo, descricao, ativo)
        self.votos = votos

    def adicionar_voto_Jhony(self):
        self.votos += 1

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class EnquetePrivada_Jhony:
    def __init__(self, titulo):
        self.__titulo = titulo

    def get_titulo_Jhony(self):
        return self.__titulo

    def set_titulo_Jhony(self, novo_titulo):
        self.__titulo = novo_titulo

    def titulo_maiusculo_Jhony(self):
        return self.__titulo.upper()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
import sqlite3

class EnqueteDB_Jhony:
    def __init__(self, titulo, descricao):
        self.titulo = titulo
        self.descricao = descricao

    def salvar_no_banco_Jhony(self):
        conn = sqlite3.connect("enquetes.db")
        cursor = conn.cursor()
        cursor.execute("CREATE TABLE IF NOT EXISTS enquetes (titulo TEXT, descricao TEXT)")
        cursor.execute("INSERT INTO enquetes VALUES (?, ?)", (self.titulo, self.descricao))
        conn.commit()
        conn.close()

    def mostrar_Jhony(self):
        return f"{self.titulo} - {self.descricao}"

# Polimorfismo
class EnqueteRapida_Jhony(EnqueteDB_Jhony):
    def mostrar_Jhony(self):
        return f"[RÁPIDA] {self.titulo.upper()}!"

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5
# 📘 SISTEMA DE GERENCIAMENTO DE ENQUETES ESCOLARES – JHONY (USANDO SQLITE)

import sqlite3

# ----------------------------
# PARTE 1 – Classe Principal
# ----------------------------
class Enquete_Jhony:
    def __init__(self, titulo, descricao, ativo):
        self.titulo = titulo
        self.descricao = descricao
        self.ativo = ativo

    def exibir_dados_Jhony(self):
        return f"Título: {self.titulo}\nDescrição: {self.descricao}\nAtiva: {self.ativo}"

# ----------------------------
# PARTE 2 – Herança e Métodos
# ----------------------------
class EnqueteComVotos_Jhony(Enquete_Jhony):
    def __init__(self, titulo, descricao, ativo, votos):
        super().__init__(titulo, descricao, ativo)
        self.votos = votos

    def adicionar_voto_Jhony(self):
        self.votos += 1

# ----------------------------
# PARTE 3 – Encapsulamento
# ----------------------------
class EnquetePrivada_Jhony:
    def __init__(self, titulo):
        self.__titulo = titulo  # atributo privado

    def get_titulo_Jhony(self):
        return self.__titulo

    def set_titulo_Jhony(self, novo_titulo):
        self.__titulo = novo_titulo

    def titulo_maiusculo_Jhony(self):
        return self.__titulo.upper()

# PARTE 4 – Banco de Dados (SQLite)
class EnqueteDB_Jhony:
    def __init__(self, titulo, descricao):
        self.titulo = titulo
        self.descricao = descricao

    def conectar_banco_Jhony(self):
        return sqlite3.connect("enquetes_jhony.db")  # Cria o banco local se não existir

    def salvar_enquete_Jhony(self):
        conn = self.conectar_banco_Jhony()
        cursor = conn.cursor()
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS enquetes (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                titulo TEXT,
                descricao TEXT
            )
        """)
        cursor.execute("INSERT INTO enquetes (titulo, descricao) VALUES (?, ?)",
                       (self.titulo, self.descricao))
        conn.commit()
        conn.close()

    def listar_enquetes_Jhony(self):
        conn = self.conectar_banco_Jhony()
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM enquetes")
        resultados = cursor.fetchall()
        conn.close()
        return resultados

    def excluir_enquete_Jhony(self, id_enquete):
        conn = self.conectar_banco_Jhony()
        cursor = conn.cursor()
        cursor.execute("DELETE FROM enquetes WHERE id = ?", (id_enquete,))
        conn.commit()
        conn.close()

# PARTE 4 – Polimorfismo
class EnqueteRapidaDB_Jhony(EnqueteDB_Jhony):
    def mostrar_Jhony(self):
        return f"[RÁPIDA] {self.titulo.upper()} - {self.descricao.upper()}"

# PARTE 5 – Interface via Terminal (SQLite)
def menu_enquetes_Jhony():
    while True:
        print("\n📊 SISTEMA DE ENQUETES ESCOLARES - JHONY (SQLite)")
        print("1. Criar nova enquete")
        print("2. Listar enquetes")
        print("3. Excluir enquete")
        print("4. Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            titulo = input("Digite o título da enquete: ")
            descricao = input("Digite a descrição da enquete: ")
            enquete = EnqueteDB_Jhony(titulo, descricao)
            enquete.salvar_enquete_Jhony()
            print("✅ Enquete salva com sucesso!")

        elif opcao == "2":
            enquete = EnqueteDB_Jhony("", "")
            enquetes = enquete.listar_enquetes_Jhony()
            if not enquetes:
                print("⚠️ Nenhuma enquete encontrada.")
            else:
                print("\n📋 Lista de Enquetes:")
                for e in enquetes:
                    print(f"ID: {e[0]} | Título: {e[1]} | Descrição: {e[2]}")

        elif opcao == "3":
            id_excluir = input("Digite o ID da enquete a ser excluída: ")
            enquete = EnqueteDB_Jhony("", "")
            enquete.excluir_enquete_Jhony(id_excluir)
            print("🗑️ Enquete excluída com sucesso.")

        elif opcao == "4":
            print("👋 Saindo do sistema. Até logo!")
            break

        else:
            print("❌ Opção inválida. Tente novamente.")

menu_enquetes_Jhony()
